# %%
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style = "whitegrid")

# %%
data_set = pd.read_csv("Data/AIML Dataset.csv")

# %%
data_set.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
data_set.shape
# Out:
# (6362620, 11)

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
data_set.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
data_set["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
data_set["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
data_set.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
data_set.isnull().sum().sum()
# Out:
# 0

# %%
data_set["step"].value_counts()
# Out:
# step
# 19     51352
# 18     49579
# 187    49083
# 235    47491
# 307    46968
#        ...
# 432        4
# 706        4
# 693        4
# 112        2
# 662        2
# Name: count, Length: 743, dtype: int64

# %%
(data_set["isFraud"].value_counts()[1] / data_set.shape[0]) * 100
# Out:
# 0.12908204481801522

# %%
round((data_set["isFraud"].value_counts()[1] / data_set.shape[0]) * 100, 2)
# Out:
# 0.13

# %%
data_set["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
data_set["type"].value_counts().plot(kind = "bar", title = "Transaction Types", color = "skyblue")
plt.xlabel("Transaction types")
plt.ylabel("Count")
plt.show()

# %%
fraud_by_type = data_set.groupby("type")["isFraud"].mean().sort_values(ascending = False)
fraud_by_type.plot(kind = "bar", title = "Fraud Rate by Type", color = "salmon")
plt.ylabel("Fraud Rate")
plt.show()

# %%
fraud_by_type
# Out:
# type
# TRANSFER    0.007688
# CASH_OUT    0.001840
# CASH_IN     0.000000
# DEBIT       0.000000
# PAYMENT     0.000000
# Name: isFraud, dtype: float64

# %%
data_set["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(data_set["amount"]), bins = 100, kde = True, color = "green")
plt.title("Transaction Amount Distribution")
plt.xlabel("log(amount + 1)")
plt.show()

# %%
sns.boxplot(data = data_set[data_set["amount"] < 50000], x = "isFraud", y = "amount")
plt.title("Amount vs isFraud (Filtered under 50k)")
plt.show()

# %%
data_set.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
data_set["balanceDiffOrig"] = data_set["oldbalanceOrg"] - data_set["newbalanceOrig"]
data_set["balanceDiffDest"] = data_set["newbalanceDest"] - data_set["oldbalanceDest"]

# %%
(data_set["balanceDiffOrig"] < 0).sum()
# Out:
# 1399253

# %%
(data_set["balanceDiffDest"] < 0).sum()
# Out:
# 1238864

# %%
frauds_per_step = data_set[data_set["isFraud"] == 1]["step"].value_counts().sort_index()
plt.plot(frauds_per_step.index, frauds_per_step.values, label = "Fraud per Step")
plt.xlabel("Step(Time)")
plt.ylabel("Number of Frauds")
plt.title("Frauds over Time")
plt.grid(True)
plt.show()

# %%
data_set.drop(columns = "step", inplace = True)

# %%
data_set.head(1)
# Out:
#       type   amount     nameOrig  oldbalanceOrg  newbalanceOrig     nameDest  \
# 0  PAYMENT  9839.64  C1231006815       170136.0       160296.36  M1979787155
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  balanceDiffOrig  \
# 0             0.0             0.0        0               0          9839.64
#
#    balanceDiffDest
# 0              0.0

# %%
top_senders = data_set["nameOrig"].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C1902386530    3
# C363736674     3
# C545315117     3
# C724452879     3
# C1784010646    3
# C1677795071    3
# C1462946854    3
# C1999539787    3
# C2098525306    3
# C400299098     3
# Name: count, dtype: int64

# %%
top_receivers = data_set["nameDest"].value_counts().head(10)

# %%
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = data_set[data_set["isFraud"] == 1]["nameOrig"].value_counts().head(10)

# %%
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C755286039     1
# C973279667     1
# C258213312     1
# C1640703547    1
# C1127265876    1
# C317779855     1
# C1064034527    1
# C1141104763    1
# C1966863341    1
# Name: count, dtype: int64

# %%
fraud_types = data_set[data_set["type"].isin(["TRANSFER", "CASH_OUT"])]

# %%
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data = fraud_types, x = "type", hue = "isFraud")
plt.title("Fraud Distribution in Transfer and Cash Out")
plt.show()

# %%
corr = data_set[["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest", "isFraud"]].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot = True, cmap = "coolwarm", fmt = "0.2f")
plt.title("Correlation Matrix")
plt.show()

# %%
zero_after_trasfer = data_set[
    (data_set["oldbalanceOrg"] > 0) &
    (data_set["newbalanceOrig"] == 0) &
    (data_set["type"].isin(["TRANSFER", "CASH_OUT"]))
]

# %%
len(zero_after_trasfer)
# Out:
# 1188074

# %%
zero_after_trasfer.head(10)
# Out:
#         type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER     181.00  C1305486145         181.00             0.0
# 3   CASH_OUT     181.00   C840083671         181.00             0.0
# 15  CASH_OUT  229133.94   C905080434       15325.00             0.0
# 19  TRANSFER  215310.30  C1670993182         705.00             0.0
# 24  TRANSFER  311685.89  C1984094095       10835.00             0.0
# 42  CASH_OUT  110414.71   C768216420       26845.41             0.0
# 47  CASH_OUT   56953.90  C1570470538        1942.02             0.0
# 51  CASH_OUT   23261.30  C2072313080       20411.53             0.0
# 60  CASH_OUT   82940.31  C1528834618        3017.87             0.0
# 72  CASH_OUT   94253.33  C1718906711       25203.05             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# ...

# %%
data_set.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0
# ...

# %%
data_model = data_set.drop(["nameOrig", "nameDest", "isFlaggedFraud"], axis = 1)

# %%
data_model.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrig  balanceDiffDest
# 0             0.0        0          9839.64              0.0
# 1             0.0        0          1864.28              0.0
# 2             0.0        1           181.00              0.0
# 3             0.0        1           181.00         -21182.0
# 4             0.0        0         11668.14              0.0

# %%
categorical = ["type"]
numeric = ["amount", "oldbalanceOrg", "newbalanceOrig", "oldbalanceDest", "newbalanceDest"]

# %%
y = data_model["isFraud"]
X = data_model.drop("isFraud", axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(drop = "first"), categorical)
    ],
    remainder = "drop"
)

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("clf", LogisticRegression(class_weight="balanced", max_iter=1000))
    ]
)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1906322
#            1       0.02      0.93      0.04      2464
#
#     accuracy                           0.95   1908786
#    macro avg       0.51      0.94      0.51   1908786
# weighted avg       1.00      0.95      0.97   1908786

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1804255,  102067],
#        [    164,    2300]])

# %%
pipeline.score(X_train, y_train)
# Out:
# 0.9464355878553175

# %%
pipeline.score(X_test, y_test)
# Out:
# 0.9464418745736819

# %%
joblib.dump(pipeline, "Fraud_Detection_Pipeline.pkl")
# Out:
# ['Fraud_Detection_Pipeline.pkl']
